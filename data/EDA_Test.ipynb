# %%
import numpy as nump
import pandas as pd 
import openpyxl

# %%
df = pd.read_excel("MID.xlsx")
df.head()
# Out:
#                       NAME                                               LINK  \
# 0       Andol 0.5mg Tablet  https://www.1mg.com/drugs/andol-0.5mg-tablet-6...
# 1  Avastin 100mg Injection  https://www.1mg.com/drugs/avastin-100mg-inject...
# 2    Actorise 40 Injection  https://www.1mg.com/drugs/actorise-40-injectio...
# 3    Actorise 25 Injection  https://www.1mg.com/drugs/actorise-25-injectio...
# 4    Actorise 60 Injection  https://www.1mg.com/drugs/actorise-60-injectio...
#
#                    CONTAINS  \
# 0       Haloperidol (0.5mg)
# 1       Bevacizumab (100mg)
# 2  Darbepoetin alfa (40mcg)
# 3  Darbepoetin alfa (25mcg)
# 4  Darbepoetin alfa (60mcg)
#
#                                         INTRODUCTION  \
# 0  Andol 0.5mg Tablet can also be used for treati...
# 1  \nAvastin 100mg Injection is an effective medi...
# 2  Actorise 40 Injection is a medicine that needs...
# 3  Actorise 25 Injection is a medicine that needs...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192807 entries, 0 to 192806
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   NAME                             192807 non-null  object
#  1   LINK                             192807 non-null  object
#  2   CONTAINS                         192807 non-null  object
#  3   INTRODUCTION                     180821 non-null  object
#  4   USES                             192807 non-null  object
#  5   BENEFITS                         192807 non-null  object
#  6   SIDE_EFFECT                      192807 non-null  object
#  7   HOW_TO_USE                       192712 non-null  object
#  8   HOW_WORKS                        192571 non-null  object
#  9   QUICK_TIPS                       191344 non-null  object
#  10  CHEMICAL_CLASS                   101473 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# NAME                                    0
# LINK                                    0
# CONTAINS                                0
# INTRODUCTION                        11986
# USES                                    0
# BENEFITS                                0
# SIDE_EFFECT                             0
# HOW_TO_USE                             95
# HOW_WORKS                             236
# QUICK_TIPS                           1463
# CHEMICAL_CLASS                      91334
# HABIT_FORMING                           0
# THERAPEUTIC_CLASS                       0
# ACTION_CLASS                       107072
# SAFETY_ADVICE_TO_ALCOHOL             9669
# SAFETY_ADVICE_TO_PREGNANCY           9673
# SAFETY_ADVICE_TO_BREAST_FEEDING      9673
# SAFETY_ADVICE_TO_DRIVING            20533
# SAFETY_ADVICE_TO_KIDNEY             14446
# SAFETY_ADVICE_TO_LIVER              14448
# dtype: int64

# %%
df.describe().T
# Out:
#                                   count  unique  \
# NAME                             192807  147872
# LINK                             192807  151007
# CONTAINS                         192807   11940
# INTRODUCTION                     180821  136870
# USES                             192807    1144
# BENEFITS                         192807  144473
# SIDE_EFFECT                      192807  121471
# HOW_TO_USE                       192712  120707
# HOW_WORKS                        192571  145988
# QUICK_TIPS                       191344  137463
# CHEMICAL_CLASS                   101473     869
# HABIT_FORMING                    192807       4
# THERAPEUTIC_CLASS                192807      22
# ACTION_CLASS                      85735     409
# SAFETY_ADVICE_TO_ALCOHOL         183138  128158
# SAFETY_ADVICE_TO_PREGNANCY       183134  140413
# SAFETY_ADVICE_TO_BREAST_FEEDING  183134  140475
# SAFETY_ADVICE_TO_DRIVING         172274  123424
# ...

# %%
df.duplicated(subset='NAME').sum()
# Out:
# np.int64(44935)

# %%
for i in df.columns:
    print('col: ', i, df.duplicated(subset=i).sum())
    print(df[i].nunique(), len(df))
    print('--'*10)
# Out:
# col:  NAME 44935
# 147872 192807
# --------------------
# col:  LINK 41800
# 151007 192807
# --------------------
# col:  CONTAINS 180867
# 11940 192807
# --------------------
# col:  INTRODUCTION 55936
# 136870 192807
# --------------------
# col:  USES 191663
# 1144 192807
# --------------------
# col:  BENEFITS 48334
# 144473 192807
# --------------------
# col:  SIDE_EFFECT 71336
# 121471 192807
# --------------------
# col:  HOW_TO_USE 72099
# 120707 192807
# --------------------
# col:  HOW_WORKS 46818
# 145988 192807
# --------------------
# col:  QUICK_TIPS 55343
# 137463 192807
# --------------------
# col:  CHEMICAL_CLASS 191937
# 869 192807
# --------------------
# col:  HABIT_FORMING 192803
# 4 192807
# --------------------
# col:  THERAPEUTIC_CLASS 192785
# 22 192807
# --------------------
# col:  ACTION_CLASS 192397
# 409 192807
# --------------------
# col:  SAFETY_ADVICE_TO_ALCOHOL 64648
# 128158 192807
# --------------------
# col:  SAFETY_ADVICE_TO_PREGNANCY 52393
# ...

# %%
# Out:
# (147872, 192807)
